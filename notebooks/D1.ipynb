# %%
print(not({})) #True
# Out:
# True

# %%
# Variable: container to store data
a="Rupesh"
a='Raj'

# %%
a=10
b=10
#same memory usage and therefore have same id
print(id(a))
print(id(b))

# %%
a="Hello"
print(a)
print(not(a))
#By default value for string is true
#String are declared by single quote and double quotes
# Out:
# Hello
# False

# %%
a=10
if a:
    print("Yes")
else:
    print("No")
#+ve no. and -ve are always true
# Out:
# No

# %% [markdown]
# Boolean
# -True
# -False

# %%
a=[10]
print(a) #complete list 
print(a[0])
# if a list is empty then it is said false else treated as true
# Out:
# [10]
# 10

# %%
a={"Name":"Hello"}
print(a) #complete dict
print(a["Name"]) #particular value
print(not(a)) # since ddict contains value so it is considered true so its not would be false
# Out:
# {'Name': 'Hello'}
# Hello
# False

# %% [markdown]
# since we can write name of key as "Full Name"
# so in order to access it if dot operator usse then a.Full Name and a.FullName both cant be used
# therefore python don not use dot operator instead uses []

# %%
#ex
a={"Full Name":"Hello"}
a["Full Name"]
# Out:
# 'Hello'

# %%
a={"address":{"city":"Jaipur","Area":"Arya mains"}}
print(a["address"]["city"])
print(a["address"]["Area"])
# Out:
# Jaipur
# Arya mains

# %%
a=[10,20,30,[40,50]]
print(a[0])
print(a[1])
print(a[2])
print(a[3][0])
print(a[3][1])
print(a[-1])
# Out:
# 10
# 20
# 30
# 40
# 50
# [40, 50]

# %%
a={
    "catalogFeedType":"catalog_listing_page",

    "enable": False,

    "catalogs":[
        {
            "id": 3050654,

            "hero_pid": 15293867,

            "name": "Mangalsutra",

            "popular": False,

            "has_mrp": True,

            "is_added_to_wishlist": False,

            "assured_details": {

                "is_assured": False,

                "message": "Best quality products from trusted suppliers."
            }
        }
    ]
}
print(a["catalogFeedType"])
print(a["enable"])
print(a["catalogs"][0]["id"])
print(a["catalogs"][0]["hero_pid"])
print(a["catalogs"][0]["name"])
print(a["catalogs"][0]["popular"])
print(a["catalogs"][0]["has_mrp"])
print(a["catalogs"][0]["is_added_to_wishlist"])
print(a["catalogs"][0]["assured_details"]["is_assured"])
print(a["catalogs"][0]["assured_details"]["message"])
# Out:
# catalog_listing_page
# False
# 3050654
# 15293867
# Mangalsutra
# False
# True
# False
# False
# Best quality products from trusted suppliers.
