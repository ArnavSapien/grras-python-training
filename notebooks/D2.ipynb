# %%
c=0
if not(c):
    print("Zero")
else:
    print("Student present")
# Out:
# Zero

# %%
dict={
    "friends":{
        "BestFriend":"A",
        "JustFriend":"B",
        "PlainFriend":"C"
    }
}
print(dict["friends"]["BestFriend"])
print(dict["friends"]["JustFriend"])
print(dict["friends"]["PlainFriend"])
# Out:
# A
# B
# C

# %%
dict={
    "Address":[
        "Jaipur","Kukas","Chandwaji","TN"
    ],
    "Jaipur":{
        "City":"SindhiCamp",
        "Area":"BusStand"
    }
}
print(dict["Address"][0])
print(dict["Address"][1])
print(dict["Address"][2])
print(dict["Address"][3])
print(dict["Jaipur"]["City"])
print(dict["Jaipur"]["Area"])
# Out:
# Jaipur
# Kukas
# Chandwaji
# TN
# SindhiCamp
# BusStand

# %%
#Arithmetic operator
a=100
b=20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(5**2)
# Out:
# 120
# 80
# 2000
# 5.0
# 0
# 25

# %%
print(10*2+10/5+2)
# Out:
# 24.0

# %%
#relational operator
a=10
b=20
print(a>b)
print(a<b)
print(a<=b)
print(a>=b)
print(a==b)
print(a!=b)
# Out:
# False
# True
# True
# False
# False
# True

# %%
# print(a=b) here value assign not possible
print(a=b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # print(a=b) here value assign not possible
# ----> 2 print(a=b)
#
# TypeError: print() got an unexpected keyword argument 'a'

# %%
#swapping
a=10
b=20
a,b=b,a
print(a,b)
# Out:
# 20 10

# %%
#logical and operator
print(10 and 20)
print(10 and {})
print({} and 10)
print({} and [])
#false me first condition is used whereas true uses second fellow
# Out:
# 20
# {}
# {}
# {}

# %%
#logical or operator
print(10 or 20)
print(10 or {})
print({} or 10)
print({} or [])
#isme first true use krte hai but false second wala hota hai
# Out:
# 10
# 10
# 10
# []

# %%
a=[]
b=10

print(not a or b)
# Out:
# True

# %%
#bitwise operator
a=5          #101
b=3          #011
#------------------
#(a & b)      001
#(a | b)      111
#(a ^ b)      110
#------------------
print(a & b)
print(a | b)
print(a ^ b)
# Out:
# 1
# 7
# 6

# %%
a=10
b=7
print(not(a & b))
# Out:
# False

# %%
#membership operator
a=["a","b","b","d"]
print("b" in a)
print("z" not in a)
# Out:
# True
# True

# %%
#Condition statement
a=10
if a==10:
    print("Y")
else:
    print("N")
# Out:
# Y

# %%
b=20
if b<10:
    print("b less than 10")
elif b==10:
    print("b eual to 10")
else:
    print("b greater than 10")
# Out:
# b greater than 10

# %%
marks=99
if marks>95:
    print("a")
elif marks>85:
    print("b")
elif marks>60:
    print("c")
else:
    print("fail")
# Out:
# a

# %%
dict={
    "name":"Raj",
    "email":"raj@gmail.com"
}
if dict["name"]:
    if "Raj" in dict["name"]:
        print(dict["email"])
    else:
        print("String do not have Raj")
else:
    print("Empty string")
# Out:
# raj@gmail.com

# %%
dict={
    "class":[
        10,
        11,
        12
    ],
    "student":[
        "Ram",
        "Shyam",
        "Gyanshyam"
    ]
}
Class=5
student="Chi"
if Class in dict["class"]:
    print(Class,"is present")
else:
    print(Class,"is absent")

if student in dict["student"]:
    print(student,"is present")
else:
    print(student,"is absent")
# Out:
# 5 is absent
# Chi is absent
