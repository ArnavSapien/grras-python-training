# %%
import pandas as pd

#example 1
l = [10,20,30]
df = pd.Series(data=l)
# print(df)

#example 2
d = {"name":"kunal","age":"21","roll-no":123}
df = pd.Series(data=d,index=["name","age","roll-no"])
print(df)

# suggestion
# help(pd.Series)
# pd.Series??
# Out:
# name       kunal
# age           21
# roll-no      123
# dtype: object

# %%
import pandas as pd

d = {
    "name":["kunal","dheeraj","anjali","praveen","yash","danish"],
    "roll-no":[12,13,14,15,16,17]
}
df = pd.DataFrame(data=d)
print(df)
# Out:
#       name  roll-no
# 0    kunal       12
# 1  dheeraj       13
# 2   anjali       14
# 3  praveen       15
# 4     yash       16
# 5   danish       17

# %%
import pandas as pd
df=pd.read_json("../datasets/file2.json")
print(df)
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50

# %%
print(df.head()) #returns first 5 element
print(df.tail()) #returns last 5 elements
print(df.head(-1)) #starting 4 rows
print(df.head(-2)) #starting 3 rows
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30

# %%
print(df.tail())
print(df.tail(-1))
print(df.tail(-2))
print(df.tail(-3))
print(df.tail(-4))
print(df.tail(-5))
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
#        name  roll no  marks
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
#        name  roll no  marks
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
#       name  roll no  marks
# 3  praveen    12356     40
# 4   anjali  1234567     50
#      name  roll no  marks
# 4  anjali  1234567     50
# Empty DataFrame
# Columns: [name, roll no, marks]
# Index: []

# %%
print("Shape:\n",df.shape,"\n")  #(row,column)
df.info()
print("\n")
print(df.info(verbose=False)) #undetailed
# Out:
# Shape:
#  (5, 3)
#
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      str
#  1   roll no  5 non-null      int64
#  2   marks    5 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 252.0 bytes
#
#
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Columns: 3 entries, name to marks
# dtypes: int64(2), str(1)
# memory usage: 252.0 bytes
# None

# %%
import pandas as pd
d = {
    "name":["vishal","virat","vineet"], # 3 rows
    "salary":[100,200,300] # 3 rows
}
df = pd.DataFrame(data=d)
df["marks"] = df["salary"] / 2
df["increment"] = df["salary"] + (df["salary"] / 10)
# column name change
df.rename(columns={"increment":"salary_increment"},inplace=True)
df
# Out:
#      name  salary  marks  salary_increment
# 0  vishal     100   50.0             110.0
# 1   virat     200  100.0             220.0
# 2  vineet     300  150.0             330.0
