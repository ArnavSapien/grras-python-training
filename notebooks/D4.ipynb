# %%
a=-5
b=-5
print(a is b)
# for -5 to 256 python points same address for the values
c=-6
d=-6
print(c is d)
# Out:
# True
# False

# %%
a=10
b=10.0
print(a==b)
print(a is b)
# Out:
# True
# False

# %%
n=[1,2,3]
m=[1,2,3]
print(n==m)
print(n is m)
print(id(n),id(m))
# Out:
# True
# False
# 1746876151360 1746876017088

# %%
nums=[3,2,4]
print(len(nums))
for i in range(0,len(nums)):
            for j in range(i+1,len(nums)):
                print([i,j])
# Out:
# 3
# [0, 1]
# [0, 2]
# [1, 2]
